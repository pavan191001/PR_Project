# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
Dataframe = pd.read_csv(R'C:\Users\sreen\Desktop\SEM-5\PR\updated_PR_Project_Grp_6\python\updated_WineQuality_Dataset_PY_final.csv')

# %%
Dataframe.head()
# Out:
#     type  volatile acidity  chlorides  density    pH  alcohol  quality
# 0  white              0.27      0.045   1.0010  3.00      8.8        6
# 1  white              0.30      0.049   0.9940  3.30      9.5        6
# 2  white              0.28      0.050   0.9951  3.26     10.1        6
# 3  white              0.23      0.058   0.9956  3.19      9.9        6
# 4  white              0.23      0.058   0.9956  3.19      9.9        6

# %%
Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type              6497 non-null   object
#  1   volatile acidity  6497 non-null   float64
#  2   chlorides         6497 non-null   float64
#  3   density           6497 non-null   float64
#  4   pH                6497 non-null   float64
#  5   alcohol           6497 non-null   float64
#  6   quality           6497 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 355.4+ KB

# %%
Dataframe.describe()
# Out:
#        volatile acidity    chlorides      density           pH      alcohol  \
# count       6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean           0.339666     0.056034     0.994697     3.218501    10.491801
# std            0.164636     0.035034     0.002999     0.160787     1.192712
# min            0.080000     0.009000     0.987110     2.720000     8.000000
# 25%            0.230000     0.038000     0.992340     3.110000     9.500000
# 50%            0.290000     0.047000     0.994890     3.210000    10.300000
# 75%            0.400000     0.065000     0.996990     3.320000    11.300000
# max            1.580000     0.611000     1.038980     4.010000    14.900000
#
#            quality
# count  6497.000000
# mean      5.818378
# std       0.873255
# min       3.000000
# 25%       5.000000
# 50%       6.000000
# 75%       6.000000
# max       9.000000

# %%
Dataframe.isnull().sum()
# Out:
# type                0
# volatile acidity    0
# chlorides           0
# density             0
# pH                  0
# alcohol             0
# quality             0
# dtype: int64

# %%
sb.pairplot(Dataframe)
plt.show()

# %%
Dataframe.hist(bins=20,figsize=(10,10))
plt.show()

# %%
df = Dataframe
plt.figure(figsize=[15,6])
plt.bar(df['quality'],df['pH'])
plt.xlabel('quality')
plt.ylabel('pH')
plt.show()

# %%
df = Dataframe
plt.figure(figsize=[15,6])
plt.bar(df['quality'],df['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
df = Dataframe
plt.figure(figsize=[15,6])
plt.bar(df['quality'],df['chlorides'])
plt.xlabel('quality')
plt.ylabel('chlorides')
plt.show()

# %%
df = Dataframe
plt.figure(figsize=[15,6])
plt.bar(df['quality'],df['density'])
plt.xlabel('quality')
plt.ylabel('density')
plt.show()

# %%
plt.figure(figsize=[18,7])
# plot correlation
sb.heatmap(Dataframe.corr(),annot=True)
plt.show()
